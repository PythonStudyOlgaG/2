# %% [markdown]
# <a href="https://colab.research.google.com/github/ZlataZori4/2/blob/2-4/ZZ_Lesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # %matplotlib inline
  import numpy as np
  import matplotlib.pyplot as plt
x=np.linspace(0,10,400)
plt.plot(x, np.cos(x), marker='o')
plt.plot(x, np.cos(1.5*x), marker='o')
plt.plot(x, np.cos(2.5*x), marker='o')
